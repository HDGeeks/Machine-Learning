# %% [markdown]
# # **Working with data**

# %%
import requests
from bs4 import BeautifulSoup

page = BeautifulSoup(requests.get("https://www.tagesschau.de/").text, "html.parser") #visit the page

#<a class="teaser__link" -> this is the identified pattern that leads to all articles
articleList = page.find_all("a", class_="teaser__link", href=True)

baseUrl = "https://www.tagesschau.de" #the base url; needs to be combined with the found hrefs
articles = [] #empty list to store articles
for article in articleList[:1]:
  if article["href"].startswith("/") and not article["href"].startswith("/multimedia"): #filter out unwanted elements that might cause problems
    articlePage = BeautifulSoup(requests.get(baseUrl + article["href"]).text,"html.parser") #gathering the data
    article = articlePage.find("script", type="application/ld+json").text
    print (article)
    articles.append(article)

articles[0]
# Out:
# {
#   "@context" : "https://schema.org",
#   "@type" : "NewsArticle",
#   "dateModified" : "2026-01-27T19:30:48.828Z",
#   "datePublished" : "2026-01-27T19:23:11.914Z",
#   "isAccessibleForFree" : "true",
#   "headline" : "EU-Abkommen mit Indien: Eine neue Welthandelsordnung entsteht",
#   "description" : "Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem?",
#   "keywords" : [ "Außenhandel", "Freihandel", "Indien", "EU", "Exporte" ],
#   "articleBody" : "Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem? Von Jean-Marie Magro Es tut sich etwas in der europäischen Handelspolitik. In den vergangenen Monaten hat die Europäische Union Handelsabkommen mit dem oft vernachlässigten Indonesien und den Mercosur-Staaten unterschrieben. Zweiteres hat noch Schluckauf, da das Europäische Parlament vergangene Woche mit knapper Mehrheit beschloss, es zur Prüfung an den Europäischen Gerichtshof zu überweisen. Aufgeschoben ist nicht aufgehoben, sagen die Befürworter. Außerdem könne der Vertrag vorläufig angewendet werden.  Nun der dritte Streich: In Neu-Delhi paraphierten Kommissionspräsidentin Ursula von der Leyen, Ratspräsident António Costa und Indiens Premier Narendra Modi ein Handelsabkommen, das eine Freihandelszone von fast zwei Milliarden Menschen schaffen soll. Etwa ein Jahr, meint Modi, könne es dauern, bis der Vertrag in Kraft tritt.  In Europa muss der Text erst in alle 24 Amtssprachen übersetzt, rechtlich auf Herz und Nieren geprüft, von einer qualifizierten Mehrheit der Mitgliedsländer (mindestens 15 von 27, die mehr als 65 Prozent der Bevölkerung ausmachen) und von ebenjenem Europaparlament angenommen werden. Es sind also noch einige Hürden zu nehmen. Trotzdem geben sich die Befürworter optimistisch.  Selbst Frankreich ist dafür Im Gegensatz zum Abkommen mit den Mercosur-Staaten sind große Teile der Landwirtschaft nicht Gegenstand des Vertragswerks. Gegen Mercosur hatten vor allem Rind- und Geflügelzüchter sowie Getreidebauern Stimmung gemacht. Sie beklagten, dass sich die lateinamerikanischen Bauern nicht an dieselben Regeln halten müssten wie sie. Außerdem fürchteten sie den Preiskampf gegen die Konkurrenz aus Argentinien und Brasilien. Vor allem Frankreich wehrte sich mit allen verfügbaren Mitteln gegen das Abkommen mit den Mercosur-Staaten. Dieses Mal aber ist das vollkommen anders. Die französische Regierung signalisierte bereits, dass sie großes Interesse an einer engeren Partnerschaft mit Indien habe. Die sensiblen Punkte - Rindfleisch, Geflügel, Ethanol und Getreide - sind ausgeklammert, der CO2-Grenzzoll (CBAM) soll intakt bleiben. Dafür erhofft sich Frankreich, einen bisher kaum gesättigten Markt für seine Weine, Spirituosen und Luxusgüter zu erschließen.  Hoffnung auf Wachstum Auch für Deutschland ist der indische Markt von großer Relevanz, speziell für die Automobilindustrie. Bisher wurden an der indischen Grenze Zölle in Höhe von 70 bis 110 Prozent fällig. Einige Autobauer drückten den Satz auf 35 Prozent, indem sie ihre Autos in Indien montierten. Trotzdem fahren deutsche Marken äußerst selten durchs Land. VW etwa verkaufte im Jahr 2024 nur 42.000 Pkw in Indien.  Die Zölle sollen nun auf 40 Prozent, später auf zehn Prozent fallen. Allerdings sind diese Sätze nur für ein Kontingent von 200.000 Verbrennern im Jahr vorgesehen. Der indische Markt bleibt für die europäischen Autobauer also schwer zugänglich. Doch zumindest, so die Befürworter, hätten sie nun einen Fuß in der Tür.  Am meisten profitieren sollen auf beiden Seiten die Chemieindustrie und der Maschinenbau. Auch für europäische Elektronik- und Kunststoffhersteller wird ein hohes Wachstum erwartet. Indien wiederum erhofft sich, mehr Medikamente und auch IT-Dienstleistungen in die EU zu verkaufen. Die indische Textil- und Schmuckindustrie hat wegen der hohen US-Zölle dringend Bedarf, etwa Kleidung und Leder auf anderen Märkten loszuwerden. Durch geringere Zölle möchten indische Hersteller mit Wettbewerbern aus Vietnam und Bangladesch mithalten.  Trump hat für Eile gesorgt Hauptverantwortlicher für die Beschleunigung neuer Handelsverträge auf der Welt ist US-Präsident Donald Trump. Die Handelspolitik der USA bewegt einst enge Partner dazu, neue Abkommen zu schließen. Kanadas Premier Mark Carney und Chinas Präsident Xi Jinping meldeten erst kürzlich eine Einigun ...
#   "mainEntityOfPage" : "https://www.tagesschau.de/wirtschaft/weltwirtschaft/indien-eu-freihandel-abkommen-100.html",
#   "author" : [ {
#     "@type" : "Person",
#     "name" : "Jean-Marie Magro",
#     "url" : "https://www.tagesschau.de/ausland/korrespondenten/magro-102.html"
#   } ],
#   "publisher" : {
#     "@type" : "newsMediaOrganization",
#     "name" : "tagesschau.de",
#     "url" : "https://www.tagesschau.de",
#     "logo" : {
#       "@type" : "ImageObject",
#       "url" : "https://www.tagesschau.de/favicon.svg"
#     }
#   },
#   "about" : [ {
#     "@type" : "Thing",
#     "name" : "Außenhandel",
#     "sameAs" : "https://www.tagesschau.de/thema/außenhandel"
#   }, {
#     "@type" : "Thing",
#     "name" : "Freihandel",
#     "sameAs" : "https://www.tagesschau.de/thema/freihandel"
#   }, {
#     "@type" : "Thing",
#     "name" : "Indien",
#     "sameAs" : "https://www.tagesschau.de/thema/indien"
#   }, {
#     "@type" : "Thing",
#     "name" : "EU",
#     "sameAs" : "https://www.tagesschau.de/thema/eu"
#   }, {
#     "@type" : "Thing",
#     "name" : "Exporte",
#     "sameAs" : "https://www.tagesschau.de/thema/exporte"
#   } ],
#   "image" : [ {
#     "@type" : "ImageObject",
#     "url" : "https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZEoeA/16x9-1920/containerhafen-indien-100.jpg",
#     "author" : "REUTERS",
#     "width" : 1920,
#     "height" : 1080,
#     "datePublished" : "2026-01-27T17:20:13.915+01:00",
#     "description" : "Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. "
#   }, {
#     "@type" : "ImageObject",
#     "url" : "https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZE_mU/1x1-840/containerhafen-indien-100.jpg",
#     "author" : "REUTERS",
#     "width" : 840,
#     "height" : 840,
#     "datePublished" : "2026-01-27T17:20:13.915+01:00",
#     "description" : "Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. "
#   }, {
#     "@type" : "ImageObject",
#     "url" : "https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZFGb8/4x3/containerhafen-indien-100.jpg?width=1280",
#     "author" : "REUTERS",
#     "width" : 1280,
#     "height" : 960,
#     "datePublished" : "2026-01-27T17:20:13.915+01:00",
#     "description" : "Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. "
#   } ]
# }
# '{\n  "@context" : "https://schema.org",\n  "@type" : "NewsArticle",\n  "dateModified" : "2026-01-27T19:30:48.828Z",\n  "datePublished" : "2026-01-27T19:23:11.914Z",\n  "isAccessibleForFree" : "true",\n  "headline" : "EU-Abkommen mit Indien: Eine neue Welthandelsordnung entsteht",\n  "description" : "Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem?",\n  "keywords" : [ "Außenhandel", "Freihandel", "Indien", "EU", "Exporte" ],\n  "articleBody" : "Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem? Von Jean-Marie Magro Es tut sich etwas in der europäischen Handelspolitik. In den vergangenen Monaten hat die Europäische Union Handelsabkommen mit dem oft vernachlässigten Indonesien und den Mercosur-Staaten unterschrieben. Zweiteres hat noch Schluckauf, da das Europäische Parlament vergangene Woche mit knapper Mehrheit beschloss, es zur Prüfung an den Europäischen Gerichtshof zu überweisen. Aufgeschoben ist nicht aufgehoben, sagen die Befürworter. Außerdem könne der Vertrag vorläufig angewendet werden.  Nun der dritte Streich: In Neu-Delhi paraphierten Kommissionspräsidentin Ursula von der Leyen, Ratspräsident António Costa und Indiens Premier Narendra Modi ein Handelsabkommen, das eine Freihandelszone von fast zwei Milliarden Menschen schaffen soll. Etwa ein Jahr, meint Modi, könne es dauern, bis der Vertrag in Kraft tritt.  In Europa muss der Text erst in alle 24 Amtssprachen übersetzt, rechtlich auf Herz und Nieren geprüft, von einer qualifizierten Mehrheit der Mitgliedsländer (mindestens 15 von 27, die mehr als 65 Prozent der Bevölkerung ausmachen) und von ebenjenem Europaparlament angenommen werden. Es sind also noch einige Hürden zu nehmen. Trotzdem geben sich die Befürworter optimistisch.  Selbst Frankreich ist dafür Im Gegensatz zum Abkommen mit den Mercosur-Staaten sind große Teile der Landwirtschaft nicht Gegenstand des Vertragswerks. Gegen Mercosur hatten vor allem Rind- und Geflügelzüchter sowie Getreidebauern Stimmung gemacht. Sie beklagten, dass sich die lateinamerikanischen Bauern nicht an dieselben Regeln halten müssten wie sie. Außerdem fürchteten sie den Preiskampf gegen die Konkurrenz aus Argentinien und Brasilien. Vor allem Frankreich wehrte sich mit allen verfügbaren Mitteln gegen das Abkommen mit den Mercosur-Staaten. Dieses Mal aber ist das vollkommen anders. Die französische Regierung signalisierte bereits, dass sie großes Interesse an einer engeren Partnerschaft mit Indien habe. Die sensiblen Punkte - Rindfleisch, Geflügel, Ethanol und Getreide - sind ausgeklammert, der CO2-Grenzzoll (CBAM) soll intakt bleiben. Dafür erhofft sich Frankreich, einen bisher kaum gesättigten Markt für seine Weine, Spirituosen und Luxusgüter zu erschließen.  Hoffnung auf Wachstum Auch für Deutschland ist der indische Markt von großer Relevanz, speziell für die Automobilindustrie. Bisher wurden an der indischen Grenze Zölle in Höhe von 70 bis 110 Prozent fällig. Einige Autobauer drückten den Satz auf 35 Prozent, indem sie ihre Autos in Indien montierten. Trotzdem fahren deutsche Marken äußerst selten durchs Land. VW etwa verkaufte im Jahr 2024 nur 42.000 Pkw in Indien.  Die Zölle sollen nun auf 40 Prozent, später auf zehn Prozent fallen. Allerdings sind diese Sätze nur für ein Kontingent von 200.000 Verbrennern im Jahr vorgesehen. Der indische Markt bleibt für die europäischen Autobauer also schwer zugänglich. Doch zumindest, so die Befürworter, hätten sie nun einen Fuß in der Tür.  Am meisten profitieren sollen auf beiden Seiten die Chemieindustrie und der Maschinenbau. Auch für europäische Elektronik- und Kunststoffhersteller wird ein hohes Wachstum erwartet. Indien wiederum erhofft sich, mehr Medikamente und auch IT-Dienstleistungen in die EU zu verkaufen. Die in ...

# %% [markdown]
# ---
#
#
# # **JSON**
# The data above is formatted in json format. JSON stands for **J**ava**S**cript **O**bject **N**otation and is a lightweight data exchange format.
#
# JSON is built on two structures:
#
# - A collection of name/value pairs. In various languages, this is realized as an object, record, struct, dictionary, hash table, keyed list, or associative array.
# - An ordered list of values. In most languages, this is realized as an array, vector, list, or sequence.
#
# These are universal data structures. Virtually all modern programming languages support them in one form or another. It makes sense that a data format that is interchangeable with programming languages also be based on these structures. (https://www.json.org/json-en.html)
#
# JSON can be easily processed by machines, while still remaining human-readable.
#
# The built-in Python library *json* allows working with json data from a Python environment.
# https://docs.python.org/3/library/json.html

# %%
type(articles[0])
# Out:
# str

# %%
import json

article = json.loads(articles[0].replace("\n", "")) #removing the newline characters and loading the string as json
article
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'NewsArticle',
#  'dateModified': '2026-01-27T19:30:48.828Z',
#  'datePublished': '2026-01-27T19:23:11.914Z',
#  'isAccessibleForFree': 'true',
#  'headline': 'EU-Abkommen mit Indien: Eine neue Welthandelsordnung entsteht',
#  'description': 'Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem?',
#  'keywords': ['Außenhandel', 'Freihandel', 'Indien', 'EU', 'Exporte'],
#  'articleBody': 'Die EU und Indien einigen sich auf ein Handelsabkommen - und sogar Gegner des Mercosur-Vertrags mit Südamerika zeigen sich angetan. Was ist diesmal anders? Und wer profitiert vor allem? Von Jean-Marie Magro Es tut sich etwas in der europäischen Handelspolitik. In den vergangenen Monaten hat die Europäische Union Handelsabkommen mit dem oft vernachlässigten Indonesien und den Mercosur-Staaten unterschrieben. Zweiteres hat noch Schluckauf, da das Europäische Parlament vergangene Woche mit knapper Mehrheit beschloss, es zur Prüfung an den Europäischen Gerichtshof zu überweisen. Aufgeschoben ist nicht aufgehoben, sagen die Befürworter. Außerdem könne der Vertrag vorläufig angewendet werden.  Nun der dritte Streich: In Neu-Delhi paraphierten Kommissionspräsidentin Ursula von der Leyen, Ratspräsident António Costa und Indiens Premier Narendra Modi ein Handelsabkommen, das eine Freihandelszone von fast zwei Milliarden Menschen schaffen soll. Etwa ein Jahr, meint Modi, könne es dauern, bis der Vertrag in Kraft tritt.  In Europa muss der Text erst in alle 24 Amtssprachen übersetzt, rechtlich auf Herz und Nieren geprüft, von einer qualifizierten Mehrheit der Mitgliedsländer (mindestens 15 von 27, die mehr als 65 Prozent der Bevölkerung ausmachen) und von ebenjenem Europaparlament angenommen werden. Es sind also noch einige Hürden zu nehmen. Trotzdem geben sich die Befürworter optimistisch.  Selbst Frankreich ist dafür Im Gegensatz zum Abkommen mit den Mercosur-Staaten sind große Teile der Landwirtschaft nicht Gegenstand des Vertragswerks. Gegen Mercosur hatten vor allem Rind- und Geflügelzüchter sowie Getreidebauern Stimmung gemacht. Sie beklagten, dass sich die lateinamerikanischen Bauern nicht an dieselben Regeln halten müssten wie sie. Außerdem fürchteten sie den Preiskampf gegen die Konkurrenz aus Argentinien und Brasilien. Vor allem Frankreich wehrte sich mit allen verfügbaren Mitteln gegen das Abkommen mit den Mercosur-Staaten. Dieses Mal aber ist das vollkommen anders. Die französische Regierung signalisierte bereits, dass sie großes Interesse an einer engeren Partnerschaft mit Indien habe. Die sensiblen Punkte - Rindfleisch, Geflügel, Ethanol und Getreide - sind ausgeklammert, der CO2-Grenzzoll (CBAM) soll intakt bleiben. Dafür erhofft sich Frankreich, einen bisher kaum gesättigten Markt für seine Weine, Spirituosen und Luxusgüter zu erschließen.  Hoffnung auf Wachstum Auch für Deutschland ist der indische Markt von großer Relevanz, speziell für die Automobilindustrie. Bisher wurden an der indischen Grenze Zölle in Höhe von 70 bis 110 Prozent fällig. Einige Autobauer drückten den Satz auf 35 Prozent, indem sie ihre Autos in Indien montierten. Trotzdem fahren deutsche Marken äußerst selten durchs Land. VW etwa verkaufte im Jahr 2024 nur 42.000 Pkw in Indien.  Die Zölle sollen nun auf 40 Prozent, später auf zehn Prozent fallen. Allerdings sind diese Sätze nur für ein Kontingent von 200.000 Verbrennern im Jahr vorgesehen. Der indische Markt bleibt für die europäischen Autobauer also schwer zugänglich. Doch zumindest, so die Befürworter, hätten sie nun einen Fuß in der Tür.  Am meisten profitieren sollen auf beiden Seiten die Chemieindustrie und der Maschinenbau. Auch für europäische Elektronik- und Kunststoffhersteller wird ein hohes Wachstum erwartet. Indien wiederum erhofft sich, mehr Medikamente und auch IT-Dienstleistungen in die EU zu verkaufen. Die indische Textil- und Schmuckindustrie hat wegen der hohen US-Zölle dringend Bedarf, etwa Kleidung und Leder auf anderen Märkten loszuwerden. Durch geringere Zölle möchten indische Hersteller mit Wettbewerbern aus Vietnam und Bangladesch mithalten.  Trump hat für Eile gesorgt Hauptverantwortlicher für die Beschleunigung neuer Handelsverträge auf der Welt ist US-Präsident Donald Trump. Die Handelspolitik der USA bewegt einst enge Partner dazu, neue Abkommen zu schließen. Kanadas Premier Mark Carney und Chinas Präsident Xi Jinping meldeten erst kürzlich eine Einigung. ...
#  'mainEntityOfPage': 'https://www.tagesschau.de/wirtschaft/weltwirtschaft/indien-eu-freihandel-abkommen-100.html',
#  'author': [{'@type': 'Person',
#    'name': 'Jean-Marie Magro',
#    'url': 'https://www.tagesschau.de/ausland/korrespondenten/magro-102.html'}],
#  'publisher': {'@type': 'newsMediaOrganization',
#   'name': 'tagesschau.de',
#   'url': 'https://www.tagesschau.de',
#   'logo': {'@type': 'ImageObject',
#    'url': 'https://www.tagesschau.de/favicon.svg'}},
#  'about': [{'@type': 'Thing',
#    'name': 'Außenhandel',
#    'sameAs': 'https://www.tagesschau.de/thema/außenhandel'},
#   {'@type': 'Thing',
#    'name': 'Freihandel',
#    'sameAs': 'https://www.tagesschau.de/thema/freihandel'},
#   {'@type': 'Thing',
#    'name': 'Indien',
#    'sameAs': 'https://www.tagesschau.de/thema/indien'},
#   {'@type': 'Thing',
#    'name': 'EU',
#    'sameAs': 'https://www.tagesschau.de/thema/eu'},
#   {'@type': 'Thing',
#    'name': 'Exporte',
#    'sameAs': 'https://www.tagesschau.de/thema/exporte'}],
#  'image': [{'@type': 'ImageObject',
#    'url': 'https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZEoeA/16x9-1920/containerhafen-indien-100.jpg',
#    'author': 'REUTERS',
#    'width': 1920,
#    'height': 1080,
#    'datePublished': '2026-01-27T17:20:13.915+01:00',
#    'description': 'Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. '},
#   {'@type': 'ImageObject',
#    'url': 'https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZE_mU/1x1-840/containerhafen-indien-100.jpg',
#    'author': 'REUTERS',
#    'width': 840,
#    'height': 840,
#    'datePublished': '2026-01-27T17:20:13.915+01:00',
#    'description': 'Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. '},
#   {'@type': 'ImageObject',
#    'url': 'https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZFGb8/4x3/containerhafen-indien-100.jpg?width=1280',
#    'author': 'REUTERS',
#    'width': 1280,
#    'height': 960,
#    'datePublished': '2026-01-27T17:20:13.915+01:00',
#    'description': 'Lastwagen mit Schiffscontainern stehen im Jawaharlal Nehru Port in Navi Mumbai, Indien. '}]}

# %% [markdown]
# According to the conversion table below, the json file is converted to their corresponding Python objects:
#
# JSON |Python
# ---|---
# object|dict
# array|list
# string|str
# number (int)|int
# number (real)|float
# true|True
# false|False
# null|None

# %%
type(article)
# Out:
# dict

# %%
article.keys()
# Out:
# dict_keys(['@context', '@type', 'dateModified', 'datePublished', 'isAccessibleForFree', 'headline', 'description', 'keywords', 'articleBody', 'mainEntityOfPage', 'author', 'publisher', 'about', 'image'])

# %%
article["image"][0]['url'] #the value of the "image" key is a list of more dictionaries
# Out:
# 'https://images.tagesschau.de/image/d2527695-8589-46ea-b913-f105c01f8d86/AAABnABBbeY/AAABmyZEoeA/16x9-1920/containerhafen-indien-100.jpg'

# %% [markdown]
# The opposite process is also possible, like converting a dictionary to a json representation:

# %%
exampleDict = {1 : "one", 2 : "two"}
exampleDict
# Out:
# {1: 'one', 2: 'two'}

# %%
jsonDict = json.dumps(exampleDict)
jsonDict
# Out:
# '{"1": "one", "2": "two"}'

# %%
json.loads(jsonDict) #note that in the process, the keys have been converted to strings!!!
# Out:
# {'1': 'one', '2': 'two'}

# %%
exampleDict[1]
# Out:
# 'one'

# %%
json.loads(jsonDict)[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 json.loads(jsonDict)[1]
#
# KeyError: 1

# %%
json.loads(jsonDict)['1']

# %% [markdown]
# As indicated by its nature as a data exchange format, it is possible to save json objects as files. The convention is to use *.json* as file ending.

# %%
#display contents of current location
# !ls

# %%
#write dictionary to .json
with open("example.json", "w") as f:
  json.dump(exampleDict, f)

# %%
# !ls

# %%
#read it back to from file
with open("example.json", "r") as f:
  print(json.load(f))

# %% [markdown]
# ***Note the difference between *load()* and *loads()*!!!***
#
# Both methods deserialize json objects to Python, but they expect a different input type:
#
# - loads(): expects a string (or bytes, or bytearray)
# - load(): expects a file object
#
# The same applies to dump(s) accordingly; dump() serializes to a file object, which is used for writing json to files. dumps() serializes to a json formatted string Object.

# %% [markdown]
# ---
#
#
# # **File I/O**
# Instead of just printing the output of a program, it is also possible to write the output of a program to a file for later use.
# Within a Python program, a file is represented as a *file object*
#
# File objects are created with the *open* function. By providing a file path to the *open()* function, a program is able to read and manipulate the underlying file.
#
# https://docs.python.org/3/glossary.html#term-file-object
# https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files

# %%
#writing a string to a file
with open("example.txt", "w") as f:
  f.write("This is an example")

# %%
# !ls

# %%
#reading a file to a string
with open("example.txt", "r") as f:
  print(f.read()) #reads the entire file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 #reading a file to a string
# ----> 2 with open("example.txt", "r") as f:
#       3   print(f.read()) #reads the entire file
#
# File ~/Desktop/Machine Learning/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %% [markdown]
# In the examples above, the *open()* function takes two arguments. The first is the path to the file (both relative and absolute paths are possible). The second one indicates the so-called *mode*.
#
# The mode describes how the file can be handled. Below is an overview of the most common modes:
#
# mode|description
# ---|---
# r|read-only
# w|write-only
# a|append
# r+|read and write
#
# Note that opening a file in *w* mode will overwrite an existing file with the same name. If the file does not exist, it will be created.
#
# Therefore, if the desired behavior is to add something to an existing file, the *append* mode needs to be used.

# %%
with open("example.txt", "a") as f: #using append mode to add a new line to the end of the example.txt file
  f.write("\nThis is a new line")

# %%
with open("example.txt", "r") as f:
  print(f.read())

# %%
#altering the file contents by string manipulation
with open("example.txt","r+") as f:
  content = f.read()
  content = content.replace("example", "REPLACED")
  f.seek(0) #moving back to the beginning of the file in order to overwrite it with the altered content
  f.write(content)

# %%
with open("example.txt", "r") as f:
  print(f.read())

# %% [markdown]
# Instead of processing the file contents all at once, it might be desirable to process them line by line. This reduces memory consumption as only smaller parts of a file are loaded in at once.

# %%
with open("example.txt", "r") as f:
  for line in f:
    print(line) #reading the file line by line

# %%
with open("example.txt", "r") as f:
  lines = f.readlines() #readlines reads the file line by line and returns a list with every list element being one line
  print(lines)

# %% [markdown]
# An important concept when dealing with file is character encoding:
#
#
#
# > *Character encoding is the process of assigning numbers to graphical characters, especially the written characters of human language, allowing them to be stored, transmitted, and transformed using computers. The numerical values that make up a character encoding are known as code points and collectively comprise a code space, a code page, or character map.*
#
# (https://en.wikipedia.org/wiki/Character_encoding)
#
# Encodings differ in the way how they represent characters. Encodings that use more Bits can represent a larger set of characters. This becomes especially important if characters from non-english latin characters need to be displayed:

# %%
with open("encoding.txt", "w") as f:
  f.write("This is an example\n")
  f.write("Dies sind Umlaute: ä ö ü Ä Ö Ü\n")
  f.write("Дорогие друзья!\n")

# %%
with open("encoding.txt", "r") as f:
  print(f.read())
# Out:
# This is an example
# Dies sind Umlaute: ä ö ü Ä Ö Ü
# Дорогие друзья!

# %%
with open("encoding.txt", "r",encoding="ASCII") as f:
  print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 2
#       1 with open("encoding.txt", "r",encoding="ASCII") as f:
# ----> 2   print(f.read())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/encodings/ascii.py:26, in IncrementalDecoder.decode(self, input, final)
#      25 def decode(self, input, final=False):
# ---> 26     return codecs.ascii_decode(input, self.errors)[0]
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 38: ordinal not in range(128)

# %%
with open("encoding.txt", "w",encoding="ASCII",errors='ignore') as f:
  f.write("This is an example\n")
  f.write("Dies sind Umlaute: ä ö ü Ä Ö Ü\n")
  f.write("Дорогие друзья!\n")

# %%
with open("encoding.txt", "r",encoding='cp1140') as f:
  print(f.read()) #worst case => no errors and loss of information

# %% [markdown]
# Leaving the *encoding* parameter to default will lead to using the current operating system's default character encoding.

# %% [markdown]
# ---
#
#
# # **PICKLE**
#
# If, instead of just saving data, complete data structures need to be saved, Python Objects can be (de-)serialized using the *Pickle* module.
# (https://docs.python.org/3/library/pickle.html)
#
#
# json|pickle
# ---|---
# text serialization|binary serialization
# human-readable|only machine-readable
# interoperable|python specific
# only built-in types|custom classes
# save|potentially unsafe

# %%
class Person: #example class
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def say_hello(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
import pickle
#create an instance of person and save it to file
person = Person("John", 30)
with open("person.pickle", "wb") as f: #wb is used for writing binary
  pickle.dump(person, f)

# %%
# !ls

# %%
#read pickle file
with open("person.pickle", "rb") as f:
  reloadPerson = pickle.load(f)

reloadPerson.say_hello()
# Out:
# Hello, my name is John and I am 30 years old.

# %%
class Person: #new class definition
  def __init__(self, name, age, location):
    self.name = name
    self.age = age
    self.location = location

  def say_hello(self):
    print(f"Hello, my name is {self.name}.")

  def where_am_i(self):
    print (f"I am in {self.location}")

# %% [markdown]
# Note that a change in the class definition can lead to inconsistencies!

# %%
with open("person.pickle", "rb") as f:
  reloadPerson = pickle.load(f)

reloadPerson.say_hello()
print(type(reloadPerson))

newPerson = Person("John", 30, "Vienna")
newPerson.where_am_i()
print(type(newPerson))

# %% [markdown]
# ---
#
# # **Handling Data with Pandas**
#
# - Read/Write (paths, separator, headers, indices)
#
# - Selecting columns
#
# - Sampling

# %% [markdown]
# Creating a Dataframe from a Dictionary

# %%
import pandas as pd

d = {'col1': [1, 2], 'col2': [3, 4]} #the keys will be the column names and the elements in the list will be corresponding rows
df = pd.DataFrame(data=d)

df

# %%
df['col1']

# %% [markdown]
# Creating a Dataframe from a nested List

# %%
df2 = pd.DataFrame(data=[[1,2,3],[4,5,6]]) #each inner list represents one row
df2

# %% [markdown]
# **Setting column headers**

# %%
df2.columns = ['Data 1','Data 2','Data 3'] #set column headers
df2

# %% [markdown]
# ---
#
#
# # **Writing a dataframe to a file**
#
# Saving a dataframe to a file requires specifying a file name.
# The default column separator is ",". The *sep* argument can be used to specify a different separator.

# %%
data = {'name' : ["Jack","John","Jane"],'age' : [29,39,49]}
df3 = pd.DataFrame(data=data)
df3.to_csv("names.csv")
df3

# %% [markdown]
# Note how the first column (containing the index) will also be written to the file!

# %%
# !ls

# %%
df4 = pd.read_csv("names.csv")
df4

# %% [markdown]
# Upon reading the file, a new index is created, leading to the result above!
#
# To prevent this redundant indexing, there are two options:
#
# - setting the *index* argument to false when writing to .csv

# %%
data = {'name' : ["Jack","John","Jane"],'age' : [29,39,49]}
df3 = pd.DataFrame(data=data)
df3.to_csv("names.csv",index=False)
df3 = pd.read_csv("names.csv")
df3

# %% [markdown]
# - specifying an index column during reading

# %%
data = {'name' : ["Jack","John","Jane"],'age' : [29,39,49]}
df3 = pd.DataFrame(data=data)
df3.to_csv("names.csv")
df3 = pd.read_csv("names.csv",index_col=0)
df3

# %% [markdown]
# **It is important that the separator remains consistent across writing and reading the file:**

# %%
data = {'name' : ["Jack","John","Jane"],'age' : [29,39,49],'biography':['Hi, my name is ...',"I am an ...","This is ..."]}
df3 = pd.DataFrame(data=data)
df3.to_csv("names.csv",sep=";")
df3 = pd.read_csv("names.csv",index_col=0) #sep defaults to , -> trying to parse the comma in "Hi, my ..." as separator!
df3

# %% [markdown]
# **Sampling**
#
# Sampling describes the process of (randomly) drawing samples out of a Dataframe.
#
# The *sample* method allows for both drawing an amount of samples (specified by an integer) or a fraction of the dataset as samples (specified by a float).
#
# In the example of sampling it becomes apparent why the index is important. Without an index, it would not always be possible to keep track of which rows were drawn.

# %%
df3 = pd.read_csv("names.csv",sep=";",index_col=0)
integerSample = df3.sample(n=2)
integerSample

# %%
fractionSample = df3.sample(frac=0.33)
fractionSample

# %% [markdown]
# It is not possible to draw a fraction of a column as sample. Therefore, the amount of samples drawn is rounded up or down (depending of which is closer)

# %%
fractionSample = df3.sample(frac=0.49)
fractionSample

# %%
fractionSample = df3.sample(frac=0.5)
fractionSample

# %% [markdown]
# Sample a portion of a dataset and remove the sampled rows from the original

# %%
df3

# %%
sampled = df3.sample(n=1)
sampled

# %%
df3

# %%
df3.drop(sampled.index) #use the index as unique identifier and delete the specified indices from the original data
