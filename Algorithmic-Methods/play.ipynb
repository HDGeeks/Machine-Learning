# %%
words = ["finding","ending","end"]
for word in words:
    if word.endswith("ing"):
        print(word)
    if word.startswith("end"):
        print(word)
# Out:
# finding
# ending
# ending
# end

# %%
words = ["finding","ending","end"]
for word in words:
    if word.endswith("ing"):
        print(word)
    elif word.startswith("end"):
        print(word)
# Out:
# finding
# ending
# end

# %%
import re
numbers = [1,5,7.5,115.555,.66]
for number in numbers:
    if re.search(r"^\d*\.\d+$",str(number)): # decimal of any length followed by a dot followed by a decimal of any length
        print (number)
# Out:
# 7.5
# 115.555
# 0.66
