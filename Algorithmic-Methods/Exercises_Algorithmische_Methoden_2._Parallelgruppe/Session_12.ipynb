# %% [markdown]
# # Data Visualization Exercise
#
# In dieser Übung arbeiten wir mit Matplotlib, um schrittweise eine Visualisierung zu erstellen und zu verbessern.
#
# Wir verwenden Beispieldaten, um verschiedene Visualisierungstechniken zu demonstrieren.
#
#
# https://matplotlib.org/stable/users/explain/quick_start.html

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data

np.random.seed(42)  # zur Reproduzierbarkeit
x = np.linspace(0, 10, 50)
y = np.sin(x) + np.random.normal(0, 0.1, 50)

# %% [markdown]
# ## Task 1: Basic Plot
#
# Erstellen Sie ein Liniendiagramm der Datenpunkte. Ihr Diagramm sollte Folgendes enthalten:
# - Ein Gitternetz
# - Achsenbeschriftungen
# - Einen Titel
# - Sowohl die Streupunkte als auch eine Verbindungslinie

# %%
# Your code here

# %% [markdown]
# ## Task 2: Add Statistics
#
# Berechnen und in das Diagramm einfügen:
# - Linie für den Minimalwert
# - Linie für den Maximalwert
# - Linie für den Mittelwert
#
# Verwenden Sie horizontale Linien (Tipp: plt.axhline), um diese Statistiken darzustellen.

# %%
# Your code here

# %% [markdown]
# ## Task 3: Fill Between Min and Max
#
# Erzeuge einen schattierten Bereich zwischen dem Minimal- und Maximalwert.
# Hinweis: Verwende `plt.fill_between()`.

# %%
# Your code here

# %% [markdown]
# ## Task 4: Highlight Average in Red
#
# Aktualisieren Sie die Visualisierung, um die Durchschnittslinie rot hervorzuheben und sie deutlicher sichtbar zu machen.

# %%
# Your code here

# %% [markdown]
# ## Bonus Challenge
#
# Verbessern Sie die Visualisierung weiter, indem Sie:
# 1. einen gleitenden Durchschnitt hinzufügen
# 2. das Design anpassen (Farben, Schriftarten usw.)
# 3. Anmerkungen hinzufügen, um interessante Merkmale hervorzuheben
# 4. Fehlerbalken oder Konfidenzintervalle hinzufügen
